# %% [markdown]
# # Holocene Ice Analysis
#
# ### Introduction
#
# The purpose of this notebook is to analyze the dynamics of the climate over the course of the Holocene at either end of the globe using ice core records from Greenland and Antarctica. Proxies for temperature will be used wherever possible in the form of oxygen isotope data (preferred) or hydrogen isotope data. Inferred temperature will be used if no other options are available.

# %%
import pyleoclim as pyleo
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import ammonyte as amt
import seaborn as sns
import pandas as pd
import matplotlib.transforms as transforms

# %%
color_list = sns.color_palette('colorblind')

# %%
data_folder = './data/8k_ice'

# %%
data = pyleo.Lipd(data_folder)
# Out:
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# Found: 8 LiPD file(s)
# reading: GRIP.Vinther.2006.lpd
# reading: Renland.Johnsen.1992.lpd
# reading: EDML.Stenni.2010.lpd
# reading: EPICADomeC.Stenni.2010.lpd
# reading: Vostok.Vimeux.2002.lpd
# reading: GISP2.Grootes.1997.lpd
# reading: NGRIP.NGRIP.2004.lpd
# reading: TALDICE.Mezgec.2017.lpd
# Finished read: 8 records
# /var/folders/5k/0y4jsz592qq0y78c_0ddgcpm0000gn/T/ipykernel_19857/1817828534.py:1: DeprecationWarning: The Lipd class is being deprecated and will be removed in Pyleoclim v1.0.0. Functionalities will instead be handled by the pyLipd package.
#   data = pyleo.Lipd(data_folder)

# %%
lipd_series_list = data.to_LipdSeriesList()
# Out:
# extracting paleoData...
# extracting: GRIP.Vinther.2006
# extracting: Renland.Johnsen.1992
# extracting: EDML.Stenni.2010
# extracting: EPICADomeC.Stenni.2010
# extracting: Vostok.Vimeux.2002
# extracting: GISP2.Grootes.1997
# extracting: NGRIP.NGRIP.2004
# extracting: TALDICE.Mezgec.2017
# Created time series: 39 entries
# Both age and year information are available, using age
# Both age and year information are available, using age
# Both age and year information are available, using age

# %%
lipd_series_dict = {}

for series in lipd_series_list:
    ms_series = series.copy()
    print(f'{ms_series.label} : {ms_series.value_name}')
    if ms_series.label not in lipd_series_dict:
        lipd_series_dict[ms_series.label] = []
        lipd_series_dict[ms_series.label].append(series)
    else:
        lipd_series_dict[ms_series.label].append(ms_series)
# Out:
# GRIP.Vinther.2006 : depth
# GRIP.Vinther.2006 : age
# GRIP.Vinther.2006 : d18O
# Renland.Johnsen.1992 : depth
# Renland.Johnsen.1992 : age
# Renland.Johnsen.1992 : d18O
# EDML.Stenni.2010 : bagDepth
# EDML.Stenni.2010 : age
# EDML.Stenni.2010 : bagd18O
# EDML.Stenni.2010 : bagdD
# EDML.Stenni.2010 : bagDexcess
# EDML.Stenni.2010 : temperature
# EDML.Stenni.2010 : tempSource
# EDML.Stenni.2010 : tempNoElevCorrection
# EDML.Stenni.2010 : tempNoSourceCorrection
# EPICADomeC.Stenni.2010 : depth
# EPICADomeC.Stenni.2010 : age
# EPICADomeC.Stenni.2010 : temperature
# EPICADomeC.Stenni.2010 : tempSource
# EPICADomeC.Stenni.2010 : tempPartialCorrect
# EPICADomeC.Stenni.2010 : bagd18O
# EPICADomeC.Stenni.2010 : bagdD
# EPICADomeC.Stenni.2010 : bagDexcess
# Vostok.Vimeux.2002 : age
# Vostok.Vimeux.2002 : d-excess
# Vostok.Vimeux.2002 : d2H
# Vostok.Vimeux.2002 : temperature
# Vostok.Vimeux.2002 : Tsource
# GISP2.Grootes.1997 : Depth
# GISP2.Grootes.1997 : d18O
# GISP2.Grootes.1997 : age
# NGRIP.NGRIP.2004 : d18O
# NGRIP.NGRIP.2004 : year
# NGRIP.NGRIP.2004 : age
# TALDICE.Mezgec.2017 : depth
# TALDICE.Mezgec.2017 : age
# TALDICE.Mezgec.2017 : d2H
# TALDICE.Mezgec.2017 : d18O
# TALDICE.Mezgec.2017 : deuteriumExcess

# %%
index_dict = {
    'GRIP.Vinther.2006' : 2,
    'Renland.Johnsen.1992' : 2,
    'EDML.Stenni.2010' : 2,
    'EPICADomeC.Stenni.2010' : 5,
    'Vostok.Vimeux.2002' : 2,
    'GISP2.Grootes.1997' : 1,
    'NGRIP.NGRIP.2004' : 0,
    'DomeF.Uemura.2018' : 4,
    'TALDICE.Mezgec.2017' : 3,
    'WAISDivide.Cuffey.2016' : 1
}

# %%
lipd_series_dict.keys()
# Out:
# dict_keys(['GRIP.Vinther.2006', 'Renland.Johnsen.1992', 'EDML.Stenni.2010', 'EPICADomeC.Stenni.2010', 'Vostok.Vimeux.2002', 'GISP2.Grootes.1997', 'NGRIP.NGRIP.2004', 'TALDICE.Mezgec.2017'])

# %%
greenland_ms_list = []
antarctica_ms_list = []
count = 0

for label in list(lipd_series_dict.keys()):
    index = index_dict[label]
    for idx,series in enumerate(lipd_series_dict[label]):
        if idx == index:
            if series.lipd_ts['geo_meanLat'] > 0:
                series.time_unit = 'Years BP'
                greenland_ms_list.append(series)
            else:
                series.time_unit = 'Years BP'
                antarctica_ms_list.append(series)

# %%
end_time = 10000

# %% [markdown]
# Greenland analysis

# %%
greenland_ms = pyleo.MultipleSeries([series.slice((0,end_time)) for series in greenland_ms_list])
greenland_ms.stackplot(colors=color_list[:len(greenland_ms.series_list)])
# Out:
# (<Figure size 640x480 with 5 Axes>,
#  {0: <Axes: ylabel='d18O [permil]'>,
#   1: <Axes: ylabel='d18O [permil]'>,
#   2: <Axes: ylabel='d18O [permil]'>,
#   3: <Axes: ylabel='d18O [permil]'>,
#   4: <Axes: xlabel='Age [Years BP]'>})

# %%
greenland_lp = []
m = 12
tau = 4

for series in greenland_ms.series_list:
    amt_series = amt.Series(
        time=series.time,
        value=series.value,
        time_name = series.time_name,
        value_name = series.value_name,
        time_unit = series.time_unit,
        value_unit = series.value_unit,
        label = series.label,
        clean_ts=False,
        sort_ts=None
    ).convert_time_unit('Years')
    td = amt_series.embed(m=m,tau=tau)
    eps = td.find_epsilon(1)
    rm = eps['Output']
    lp = rm.laplacian_eigenmaps(w_size=20,w_incre=4).convert_time_unit('Years BP')
    greenland_lp.append(lp)
# Out:
# Initial density is 0.0180
# Initial density is not within the tolerance window, searching...
# Epsilon: 1.0000, Density: 0.0180
# Epsilon: 1.1601, Density: 0.0583
# Epsilon: 1.1601, Density: 0.0583.
# Initial density is 0.0155
# Initial density is not within the tolerance window, searching...
# Epsilon: 1.0000, Density: 0.0155
# Epsilon: 1.1727, Density: 0.0436
# Epsilon: 1.1727, Density: 0.0436.
# Initial density is 0.0129
# Initial density is not within the tolerance window, searching...
# Epsilon: 1.0000, Density: 0.0129
# Epsilon: 1.1856, Density: 0.0472
# Epsilon: 1.1856, Density: 0.0472.
# Initial density is 0.0116
# Initial density is not within the tolerance window, searching...
# Epsilon: 1.0000, Density: 0.0116
# Epsilon: 1.1918, Density: 0.0408
# Epsilon: 1.1918, Density: 0.0408.

# %%
ms = greenland_ms
lp_series_list = greenland_lp

fig,axes = plt.subplots(nrows=len(lp_series_list),ncols=1,sharex=True,figsize=(16,8))
transition_timing = []

for idx,lp_series in enumerate(lp_series_list):
    ts = lp_series
    ts.label = lp_series.label
    ts.value_name = 'FI'
    ts.value_unit = None
    ts.time_name = 'Yr'
    ts.time_unit = 'ka'
    
    ax = axes[idx]
#     if idx > 0:
#         ax = fig.add_subplot(spec[idx],sharex=axes[idx-1])
#     else:
#         ax = fig.add_subplot(spec[idx])
#     axes.append(ax)
    
    ts_smooth = amt.utils.fisher.smooth_series(ts,3)
    upper, lower = amt.utils.sampling.confidence_interval(ts)
#     transitions=detect_transitions(ts_smooth,transition_interval=(upper,lower))
#     transition_timing.append(transitions[0])

    ts.confidence_smooth_plot(
        ax=ax,
        background_series = ms.series_list[idx].slice((0,end_time)),
        transition_interval=(upper,lower),
        block_size=3,
        color=color_list[idx],
        figsize=(12,6),
        legend=True,
        lgd_kwargs={'loc':'upper left'},
        hline_kwargs={'label':None},
        background_kwargs={'ylabel':'$\delta^{18}O$ [permil]','legend':False,'linewidth':.8,'color':'grey','alpha':.8})
    
#     for transition in transitions:
#         ax.axvline(transition,color='grey',linestyle='dashed',alpha=.5)
    
    trans = transforms.blended_transform_factory(ax.transAxes, ax.transData)
    ax.text(x=-.08, y = 2.2, s = ts.label, horizontalalignment='right', transform=trans, color=color_list[idx], weight='bold')
        
#     if idx % 2 == 0:
    ax.spines['left'].set_visible(True)
    ax.spines['right'].set_visible(False)
    ax.yaxis.set_label_position('left')
    ax.yaxis.tick_left()
#     else:
#         ax.spines['left'].set_visible(False)
#         ax.spines['right'].set_visible(True)
#         ax.yaxis.set_label_position('right')
#         ax.yaxis.tick_right()
    
    ax.get_legend().remove()
    ax.set_title(None)
    ax.grid(visible=False,axis='y')
    if idx != len(lp_series_list)-1:
        ax.set_xlabel(None)
        ax.spines[['bottom']].set_visible(False)
        ax.tick_params(bottom=False)

# pyleo.savefig(fig,'./ice_core_lp.png')
# plt.show()

# %% [markdown]
# Antarctica analysis

# %%
antarctica_ms = pyleo.MultipleSeries([series.slice((0,end_time)) for series in antarctica_ms_list])
antarctica_ms.stackplot(colors=color_list[:len(antarctica_ms.series_list)])
# Out:
# (<Figure size 640x480 with 5 Axes>,
#  {0: <Axes: ylabel='bagd18O [permil]'>,
#   1: <Axes: ylabel='bagd18O [permil]'>,
#   2: <Axes: ylabel='d2H [BP]'>,
#   3: <Axes: ylabel='d18O [permil]'>,
#   4: <Axes: xlabel='Age [Years BP]'>})

# %%
for item in antarctica_ms.series_list:
    print(item.lipd_ts['pub1_doi'])
# Out:
# 10.1016/j.quascirev.2009.10.009
# 10.1016/j.quascirev.2009.10.009
# 10.1016/S0012-821X(02)00950-0
# 10.1038/s41467-017-01455-x

# %%
antarctica_lp = []
m = 12
tau = 3
eps_list= [2.2,2.2,10,2.2]

for idx,raw_series in enumerate(antarctica_ms.series_list):
    
    if not raw_series.is_evenly_spaced:
        series = raw_series.interp()
    else:
        series = raw_series
        
    amt_series = amt.Series(
        time=series.time,
        value=series.value,
        time_name = series.time_name,
        value_name = series.value_name,
        time_unit = series.time_unit,
        value_unit = series.value_unit,
        label = series.label,
        clean_ts=False,
        sort_ts=None
    ).convert_time_unit('Years')
    td = amt_series.embed(m=m,tau=tau)
    eps = td.find_epsilon(eps_list[idx])
    rm = eps['Output']
    lp = rm.laplacian_eigenmaps(w_size=20,w_incre=4).convert_time_unit('Years BP')
    antarctica_lp.append(lp)
# Out:
# Initial density is 0.0395
# Initial density is not within the tolerance window, searching...
# Epsilon: 2.3051, Density: 0.0551
# Epsilon: 2.3051, Density: 0.0551.
# Initial density is 0.0744
# Initial density is not within the tolerance window, searching...
# Epsilon: 1.9563, Density: 0.0309
# Epsilon: 2.1476, Density: 0.0622
# Epsilon: 2.0260, Density: 0.0403
# Epsilon: 2.0260, Density: 0.0403.
# Initial density is 0.0290
# Initial density is not within the tolerance window, searching...
# Epsilon: 10.2095, Density: 0.0331
# Epsilon: 10.3786, Density: 0.0370
# Epsilon: 10.5087, Density: 0.0400
# Epsilon: 10.5087, Density: 0.0400.
# Initial density is 0.0438
# Initial density is within the tolerance window!

# %%
ms = antarctica_ms
lp_series_list = antarctica_lp

fig,axes = plt.subplots(nrows=len(lp_series_list),ncols=1,sharex=True,figsize=(16,8))
transition_timing = []

for idx,lp_series in enumerate(lp_series_list):
    ts = lp_series
    ts.label = lp_series.label
    ts.value_name = 'FI'
    ts.value_unit = None
    ts.time_name = 'Yr'
    ts.time_unit = 'ka'
    
    ax = axes[idx]
#     if idx > 0:
#         ax = fig.add_subplot(spec[idx],sharex=axes[idx-1])
#     else:
#         ax = fig.add_subplot(spec[idx])
#     axes.append(ax)
    
    ts_smooth = amt.utils.fisher.smooth_series(ts,3)
    upper, lower = amt.utils.sampling.confidence_interval(ts)
#     transitions=detect_transitions(ts_smooth,transition_interval=(upper,lower))
#     transition_timing.append(transitions[0])

    ts.confidence_smooth_plot(
        ax=ax,
        background_series = ms.series_list[idx].slice((0,end_time)),
        transition_interval=(upper,lower),
        block_size=3,
        color=color_list[idx],
        figsize=(12,6),
        legend=True,
        lgd_kwargs={'loc':'upper left'},
        hline_kwargs={'label':None},
        background_kwargs={'ylabel':'$\delta^{18}O$ [permil]','legend':False,'linewidth':.8,'color':'grey','alpha':.8})
    
#     for transition in transitions:
#         ax.axvline(transition,color='grey',linestyle='dashed',alpha=.5)
    
    trans = transforms.blended_transform_factory(ax.transAxes, ax.transData)
    ax.text(x=-.08, y = 2.2, s = ts.label, horizontalalignment='right', transform=trans, color=color_list[idx], weight='bold')
        
#     if idx % 2 == 0:
    ax.spines['left'].set_visible(True)
    ax.spines['right'].set_visible(False)
    ax.yaxis.set_label_position('left')
    ax.yaxis.tick_left()
#     else:
#         ax.spines['left'].set_visible(False)
#         ax.spines['right'].set_visible(True)
#         ax.yaxis.set_label_position('right')
#         ax.yaxis.tick_right()
    
    ax.get_legend().remove()
    ax.set_title(None)
    ax.grid(visible=False,axis='y')
    if idx != len(lp_series_list)-1:
        ax.set_xlabel(None)
        ax.spines[['bottom']].set_visible(False)
        ax.tick_params(bottom=False)

# pyleo.savefig(fig,'./ice_core_lp.png')
# plt.show()

# %% [markdown]
# Compare non common time vs common time of Greenland cores with EPICADomeC d18O
#
# Document how method works, how it should be used, and areas of concern
#
# End with "can it work with event detection", elaborate on tim uncertainty.
#
# Look into "wavelet reproducing kernel" as interesting comparison/analogy for smoothing effect.
#
# What are we saying when we say the dynamics are changing, how can this allow for more thorough event detection (holistic)
#
# Question for nishant: what does a change in the dynamics really mean? is there more information stored in the eigenvectors produced by laplacian eigenmaps?

# %%
study_ms = greenland_ms.append(antarctica_ms.series_list[1].interp())
study_ms.stackplot()
# Out:
# The two series have different lengths, left: 2004 vs right: 552
# Metadata are different:
# value_name property -- left: d18O, right: bagd18O
# label property -- left: GRIP.Vinther.2006, right: EPICADomeC.Stenni.2010
# The two series have different lengths, left: 500 vs right: 552
# Metadata are different:
# value_name property -- left: d18O, right: bagd18O
# label property -- left: Renland.Johnsen.1992, right: EPICADomeC.Stenni.2010
# The two series have different lengths, left: 959 vs right: 552
# Metadata are different:
# value_name property -- left: d18O, right: bagd18O
# label property -- left: GISP2.Grootes.1997, right: EPICADomeC.Stenni.2010
# The two series have different lengths, left: 501 vs right: 552
# Metadata are different:
# value_name property -- left: d18O, right: bagd18O
# label property -- left: NGRIP.NGRIP.2004, right: EPICADomeC.Stenni.2010
# (<Figure size 640x480 with 6 Axes>,
#  {0: <Axes: ylabel='d18O [permil]'>,
#   1: <Axes: ylabel='d18O [permil]'>,
#   2: <Axes: ylabel='d18O [permil]'>,
#   3: <Axes: ylabel='d18O [permil]'>,
#   4: <Axes: ylabel='bagd18O [permil]'>,
#   5: <Axes: xlabel='Age [Years BP]'>})

# %%
study_lp = []
m = 12
tau = 4

for idx,series in enumerate(study_ms.series_list):
    amt_series = amt.Series(
        time=series.time,
        value=series.value,
        time_name = series.time_name,
        value_name = series.value_name,
        time_unit = series.time_unit,
        value_unit = series.value_unit,
        label = series.label,
        clean_ts=False,
        sort_ts=None
    ).convert_time_unit('Years').interp().detrend(method='savitzky-golay',keep_log=True)
    td = amt_series.embed(m,tau)
    eps = td.find_epsilon(1)
    rm = eps['Output']
    lp = rm.laplacian_eigenmaps(w_size=20,w_incre=4).convert_time_unit('Years BP')
    study_lp.append(lp)
# Out:
# Initial density is 0.1714
# Initial density is not within the tolerance window, searching...
# Epsilon: 0.0000, Density: 0.0000
# Epsilon: 0.5000, Density: 0.0027
# Epsilon: 0.5000, Density: 0.0027
# Epsilon: 0.7367, Density: 0.0259
# Epsilon: 0.7367, Density: 0.0259
# Epsilon: 0.8570, Density: 0.0705
# Epsilon: 0.8570, Density: 0.0705
# Epsilon: 0.7545, Density: 0.0306
# Epsilon: 0.7545, Density: 0.0306
# Epsilon: 0.8517, Density: 0.0678
# Epsilon: 0.8517, Density: 0.0678
# Epsilon: 0.7625, Density: 0.0328
# Epsilon: 0.7625, Density: 0.0328
# Epsilon: 0.8484, Density: 0.0662
# Epsilon: 0.8484, Density: 0.0662
# Epsilon: 0.7675, Density: 0.0343
# Epsilon: 0.7675, Density: 0.0343
# Epsilon: 0.8460, Density: 0.0650
# Epsilon: 0.8460, Density: 0.0650
# Epsilon: 0.7708, Density: 0.0353
# Epsilon: 0.7708, Density: 0.0353
# Epsilon: 0.8442, Density: 0.0642
# Epsilon: 0.8442, Density: 0.0642
# Epsilon: 0.7732, Density: 0.0361
# Epsilon: 0.7732, Density: 0.0361
# Epsilon: 0.8428, Density: 0.0635
# Epsilon: 0.8428, Density: 0.0635
# Epsilon: 0.7753, Density: 0.0368
# Epsilon: 0.7753, Density: 0.0368
# Epsilon: 0.8415, Density: 0.0629
# Epsilon: 0.8415, Density: 0.0629
# Epsilon: 0.7771, Density: 0.0373
# Epsilon: 0.7771, Density: 0.0373
# Epsilon: 0.8405, Density: 0.0624
# Epsilon: 0.8405, Density: 0.0624
# Epsilon: 0.7785, Density: 0.0377
# Epsilon: 0.7785, Density: 0.0377
# Epsilon: 0.8397, Density: 0.0620
# Epsilon: 0.8397, Density: 0.0620
# Epsilon: 0.7796, Density: 0.0381
# Epsilon: 0.7796, Density: 0.0381
# Epsilon: 0.8390, Density: 0.0617
# Epsilon: 0.8390, Density: 0.0617
# Epsilon: 0.7805, Density: 0.0384
# Epsilon: 0.7805, Density: 0.0384
# Epsilon: 0.8385, Density: 0.0614
# Epsilon: 0.8385, Density: 0.0614
# Epsilon: 0.7813, Density: 0.0387
# Epsilon: 0.7813, Density: 0.0387
# Epsilon: 0.8380, Density: 0.0612
# Epsilon: 0.8380, Density: 0.0612
# Epsilon: 0.7820, Density: 0.0389
# Epsilon: 0.7820, Density: 0.0389
# Epsilon: 0.8375, Density: 0.0610
# Epsilon: 0.8375, Density: 0.0610
# Epsilon: 0.7826, Density: 0.0391
# Epsilon: 0.7826, Density: 0.0391
# Epsilon: 0.8371, Density: 0.0608
# Epsilon: 0.8371, Density: 0.0608
# Epsilon: 0.7831, Density: 0.0393
# Epsilon: 0.7831, Density: 0.0393
# Epsilon: 0.8367, Density: 0.0606
# Epsilon: 0.8367, Density: 0.0606
# Epsilon: 0.7837, Density: 0.0395
# Epsilon: 0.7837, Density: 0.0395
# Epsilon: 0.8362, Density: 0.0604
# Epsilon: 0.8362, Density: 0.0604
# Epsilon: 0.7843, Density: 0.0397
# Epsilon: 0.7843, Density: 0.0397
# Epsilon: 0.8358, Density: 0.0602
# Epsilon: 0.8358, Density: 0.0602
# Epsilon: 0.7849, Density: 0.0399
# Epsilon: 0.7849, Density: 0.0399
# Epsilon: 0.8354, Density: 0.0600
# Epsilon: 0.8354, Density: 0.0600.
# Initial density is 0.0446
# Initial density is within the tolerance window!
# Initial density is 0.0386
# Initial density is not within the tolerance window, searching...
# Epsilon: 1.0000, Density: 0.0386
# Epsilon: 1.0570, Density: 0.0570
# Epsilon: 1.0570, Density: 0.0570.
# Initial density is 0.0219
# Initial density is not within the tolerance window, searching...
# Epsilon: 1.0000, Density: 0.0219
# Epsilon: 1.1406, Density: 0.0588
# Epsilon: 1.1406, Density: 0.0588.
# Initial density is 0.0022
# Initial density is not within the tolerance window, searching...
# Epsilon: 1.4783, Density: 0.0120
# Epsilon: 1.8585, Density: 0.0661
# Epsilon: 1.6978, Density: 0.0341
# Epsilon: 1.8568, Density: 0.0655
# Epsilon: 1.7015, Density: 0.0347
# Epsilon: 1.8544, Density: 0.0650
# Epsilon: 1.7047, Density: 0.0353
# Epsilon: 1.8518, Density: 0.0643
# Epsilon: 1.7084, Density: 0.0358
# Epsilon: 1.8505, Density: 0.0639
# Epsilon: 1.7119, Density: 0.0362
# Epsilon: 1.8500, Density: 0.0637
# Epsilon: 1.7126, Density: 0.0363
# Epsilon: 1.8498, Density: 0.0637
# Epsilon: 1.7129, Density: 0.0363
# Epsilon: 1.8496, Density: 0.0636
# Epsilon: 1.7132, Density: 0.0364
# Epsilon: 1.8495, Density: 0.0636
# Epsilon: 1.7134, Density: 0.0364
# Epsilon: 1.8493, Density: 0.0636
# Epsilon: 1.7135, Density: 0.0364
# Epsilon: 1.8491, Density: 0.0635
# Epsilon: 1.7139, Density: 0.0365
# Epsilon: 1.8490, Density: 0.0635
# Epsilon: 1.7144, Density: 0.0366
# Epsilon: 1.8487, Density: 0.0634
# Epsilon: 1.8487, Density: 0.0634
# Epsilon: 1.7817, Density: 0.0481
# Epsilon: 1.7817, Density: 0.0481.

# %%
ms = study_ms
lp_series_list = study_lp

SMALL_SIZE = 16
MEDIUM_SIZE = 20
BIGGER_SIZE = 25

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

fig,axes = plt.subplots(nrows=len(lp_series_list),ncols=1,sharex=True,figsize=(16,20),gridspec_kw={'height_ratios':[3,1,1,1,1,1]})
transition_timing = []

for idx,lp_series in enumerate(lp_series_list):
    ts = lp_series
    ts.label = lp_series.label
    ts.value_name = 'FI'
    ts.value_unit = None
    ts.time_name = 'Yr'
    ts.time_unit = 'ka'

    ax = axes[idx+1]
    ts_smooth = amt.utils.fisher.smooth_series(ts,3)
    upper, lower = amt.utils.sampling.confidence_interval(ts)
    transitions=detect_transitions(ts_smooth,transition_interval=(upper,lower))
    
    transition_timing.append(transitions[0])

    ts.confidence_smooth_plot(
        ax=ax,
        background_series = ms.series_list[idx].slice((0,2500)),
        transition_interval=(upper,lower),
        block_size=3,
        color=color_list[idx],
        figsize=(12,6),
        legend=True,
        lgd_kwargs={'loc':'upper left'},
        hline_kwargs={'label':None},
        background_kwargs={'ylabel':'$\delta^{18}O$ [permil]','legend':False,'linewidth':.8,'color':'grey','alpha':.8})

    ax.axvline(transition_timing[idx],color='grey',linestyle='dashed',alpha=.5)
    
    trans = transforms.blended_transform_factory(ax.transAxes, ax.transData)
    ax.text(x=-.08, y = 2.5, s = ts.label, horizontalalignment='right', transform=trans, color=color_list[idx], weight='bold',fontsize=20)
        
    ax.spines['left'].set_visible(True)
    ax.spines['right'].set_visible(False)
    ax.yaxis.set_label_position('left')
    ax.yaxis.tick_left()
    ax.get_legend().remove()
    ax.set_title(None)
    ax.grid(visible=False,axis='y')
    if idx != len(group_names)-1:
        ax.set_xlabel(None)
        ax.spines[['bottom']].set_visible(False)
        ax.tick_params(bottom=False)
    ax.xaxis.label.set_fontsize(25)
    ax.yaxis.label.set_fontsize(25)
    ax.set_yticks(ticks=np.array([0,5]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 16
#      13 plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
#      14 plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
# ---> 16 fig,axes = plt.subplots(nrows=len(lp_series_list),ncols=1,sharex=True,figsize=(16,20),gridspec_kw={'height_ratios':[3,1,1,1,1,1]})
#      17 transition_timing = []
#      19 for idx,lp_series in enumerate(lp_series_list):
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:1475, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1331 """
#    1332 Create a figure and a set of subplots.
#    1333
#    (...)
#    1472
#    1473 """
#    1474 fig = figure(**fig_kw)
# -> 1475 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1476                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1477                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1478                    width_ratios=width_ratios)
#    1479 return fig, axs
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/figure.py:891, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     887         raise ValueError("'width_ratios' must not be defined both as "
#     888                          "parameter and as key in 'gridspec_kw'")
#     889     gridspec_kw['width_ratios'] = width_ratios
# --> 891 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#     892 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     893                   subplot_kw=subplot_kw)
#     894 return axs
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/figure.py:1514, in FigureBase.add_gridspec(self, nrows, ncols, **kwargs)
#    1475 """
#    1476 Return a `.GridSpec` that has this figure as a parent.  This allows
#    1477 complex layout of Axes in the figure.
#    (...)
#    1510
#    1511 """
#    1513 _ = kwargs.pop('figure', None)  # pop in case user has added this...
# -> 1514 gs = GridSpec(nrows=nrows, ncols=ncols, figure=self, **kwargs)
#    1515 return gs
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/gridspec.py:379, in GridSpec.__init__(self, nrows, ncols, figure, left, bottom, right, top, wspace, hspace, width_ratios, height_ratios)
#     376 self.hspace = hspace
#     377 self.figure = figure
# --> 379 super().__init__(nrows, ncols,
#     380                  width_ratios=width_ratios,
#     381                  height_ratios=height_ratios)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/gridspec.py:55, in GridSpecBase.__init__(self, nrows, ncols, height_ratios, width_ratios)
#      52     raise ValueError(
#      53         f"Number of columns must be a positive integer, not {ncols!r}")
#      54 self._nrows, self._ncols = nrows, ncols
# ---> 55 self.set_height_ratios(height_ratios)
#      56 self.set_width_ratios(width_ratios)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/gridspec.py:133, in GridSpecBase.set_height_ratios(self, height_ratios)
#     131     height_ratios = [1] * self._nrows
#     132 elif len(height_ratios) != self._nrows:
# --> 133     raise ValueError('Expected the given number of height ratios to '
#     134                      'match the number of rows of the grid')
#     135 self._row_height_ratios = height_ratios
#
# ValueError: Expected the given number of height ratios to match the number of rows of the grid
